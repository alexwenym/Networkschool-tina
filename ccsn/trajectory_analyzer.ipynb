# %%
import numpy as np
from nugridpy import ascii_table as at
import matplotlib.pyplot as plt

# %%
traj1 = np.genfromtxt('ccsn_cases/ccsn_cburning/trajectory_ccsn_cburning.input', skip_header=7)
traj2 = np.genfromtxt('ccsn_cases/ccsn_gammaprocess/trajectory_ccsn_gammaprocess.input', skip_header=7)
traj3 = np.genfromtxt('ccsn_cases/ccsn_oburning/trajectory_ccsn_oburning.input', skip_header=7)
traj4 = np.genfromtxt('ccsn_cases/ccsn_siburning/trajectory_ccsn_siburning.input', skip_header=7)
trajs = [traj1, traj2, traj3, traj4]

# %%
traj_cols = traj.T
traj_cols = traj_cols[0:3]
traj = traj_cols.T

# %%
traj

# %%
#np.savetxt("trajectory.input", traj, delimiter=" ")

# %%
len(traj_cols[0])
# Out:
# 230

# %%
plt.plot(traj_cols[0], traj_cols[1])

# %%
plt.plot(traj_cols[0], traj_cols[2])

# %%
# plotting 
for traj in trajs: 
    traj_cols = traj.T
    traj_cols = traj_cols[0:3]
    traj = traj_cols.T
    
    plt.plot(traj_cols[0], traj_cols[1], marker='.')
    plt.xlim(-0.5,1)

# %%
traj4
traj_cols = traj4.T
traj_cols = traj_cols[0:3]
traj4 = traj_cols.T

# %%
plt.plot(traj_cols[0], traj_cols[1])

# %%
traj4
# Out:
# array([[0.000000e+00, 1.765762e+00, 3.322914e+05],
#        [9.152490e-06, 3.252662e+00, 1.069005e+06],
#        [1.830498e-05, 4.739563e+00, 1.805719e+06],
#        [2.754945e-05, 4.739483e+00, 1.805628e+06],
#        [3.702736e-05, 4.739402e+00, 1.805534e+06],
#        [4.674460e-05, 4.739318e+00, 1.805438e+06],
#        [5.670721e-05, 4.739232e+00, 1.805340e+06],
#        [6.692139e-05, 4.739144e+00, 1.805239e+06],
#        [7.739349e-05, 4.739053e+00, 1.805136e+06],
#        [8.813002e-05, 4.738960e+00, 1.805030e+06],
#        [9.913766e-05, 4.738865e+00, 1.804922e+06],
#        [1.104233e-04, 4.738768e+00, 1.804810e+06],
#        [1.219938e-04, 4.738668e+00, 1.804696e+06],
#        [1.338566e-04, 4.738566e+00, 1.804579e+06],
#        [1.460189e-04, 4.738461e+00, 1.804459e+06],
#        [1.584883e-04, 4.738353e+00, 1.804336e+06],
#        [1.712726e-04, 4.738243e+00, 1.804210e+06],
#        [1.843797e-04, 4.738130e+00, 1.804081e+06],
# ...
