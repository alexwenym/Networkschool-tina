# %%
import numpy as np
from nugridpy import ascii_table as at
import matplotlib.pyplot as plt

# %%
traj = np.genfromtxt('trajectory.input.f10r1.5a5md3e-4', delimiter='  ')

# %%
traj_cols = traj.T
traj_cols = traj_cols[0:3]
traj = traj_cols.T

# %%
traj
# Out:
# array([[0.000000e+00, 7.173700e-02, 1.000000e+00],
#        [3.329892e+01, 7.230300e-02, 1.031900e+00],
#        [4.974608e+01, 7.288000e-02, 1.065300e+00],
#        ...,
#        [1.303643e+03, 1.144100e-02, 6.470100e-04],
#        [1.317568e+03, 1.126700e-02, 6.085300e-04],
#        [1.331771e+03, 1.109600e-02, 5.723500e-04]])

# %%
np.savetxt("trajectory.input", traj, delimiter=" ")

# %%
plt.plot(traj_cols[0], traj_cols[1])

# %%
plt.plot(traj_cols[0], traj_cols[2])
